# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhaanavee/DrugDiscovery/blob/main/drugDiscovery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install chembl_webresource_client

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#    cross_references                                           organism  \
# 0                []                                        Coronavirus
# 1                []                                 Feline coronavirus
# 2                []                                 Murine coronavirus
# 3                []                                 Canine coronavirus
# 4                []                                 Bovine coronavirus
# 5                []                             Human coronavirus 229E
# 6                []                             Human coronavirus OC43
# 7                []  Middle East respiratory syndrome-related coron...
# 8                []  Severe acute respiratory syndrome-related coro...
# 9                []  Severe acute respiratory syndrome-related coro...
# 10               []    Severe acute respiratory syndrome coronavirus 2
# 11               []    Severe acute respiratory syndrome coronavirus 2
# ...

# %%
print(targets.organism[8], targets.target_chembl_id[8])
# Out:
# Severe acute respiratory syndrome-related coronavirus CHEMBL3927

# %%
selected_target = targets.target_chembl_id[8]
selected_target
# Out:
# 'CHEMBL3927'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.DataFrame.from_dict(res)
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      1480935                  []
# 1        None             None      1480936                  []
# 2        None             None      1481061                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL829584  In vitro inhibitory concentration against SARS...
# 1    CHEMBL829584  In vitro inhibitory concentration against SARS...
# 2    CHEMBL830868  In vitro inhibitory concentration against SARS...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
#
#                                      target_organism  \
# 0  Severe acute respiratory syndrome-related coro...
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df.to_csv('bioactivity_data.csv', index = False)

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
#Data Folder
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data2"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data2’: File exists

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data2"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data2"
# Out:
# total 150
# -rw------- 1 root root 152799 Feb  1 14:23 bioactivity_data.csv

# %%
! ls
# Out:
# bioactivity_data.csv  drive  gdrive  sample_data

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %%
df2 = df[df.standard_value.notna()]
df
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 256  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 257  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 258  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 259  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 260  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id                                activity_properties  \
# ...

# %%
df.isnull().sum()
# Out:
# action_type                  240
# activity_comment             259
# activity_id                    0
# activity_properties            0
# assay_chembl_id                0
# assay_description              0
# assay_type                     0
# assay_variant_accession      261
# assay_variant_mutation       261
# bao_endpoint                   0
# bao_format                     0
# bao_label                      0
# canonical_smiles               0
# data_validity_comment        230
# data_validity_description    230
# document_chembl_id             0
# document_journal               0
# document_year                  0
# ligand_efficiency             48
# molecule_chembl_id             0
# molecule_pref_name           223
# parent_molecule_chembl_id      0
# pchembl_value                 48
# potential_duplicate            0
# qudt_units                     2
# record_id                      0
# relation                       2
# src_id                         0
# ...

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)
print(mol_cid)
# Out:
# ['CHEMBL187579', 'CHEMBL188487', 'CHEMBL185698', 'CHEMBL426082', 'CHEMBL187717', 'CHEMBL365134', 'CHEMBL187598', 'CHEMBL190743', 'CHEMBL365469', 'CHEMBL188983', 'CHEMBL191575', 'CHEMBL370923', 'CHEMBL194398', 'CHEMBL196635', 'CHEMBL209287', 'CHEMBL358279', 'CHEMBL348660', 'CHEMBL379727', 'CHEMBL210525', 'CHEMBL148483', 'CHEMBL383725', 'CHEMBL118596', 'CHEMBL208732', 'CHEMBL208732', 'CHEMBL210146', 'CHEMBL210146', 'CHEMBL207458', 'CHEMBL207458', 'CHEMBL207484', 'CHEMBL207484', 'CHEMBL207207', 'CHEMBL207207', 'CHEMBL210487', 'CHEMBL210487', 'CHEMBL380470', 'CHEMBL380470', 'CHEMBL210612', 'CHEMBL210612', 'CHEMBL209667', 'CHEMBL209667', 'CHEMBL210097', 'CHEMBL210097', 'CHEMBL378674', 'CHEMBL378674', 'CHEMBL210216', 'CHEMBL210216', 'CHEMBL210195', 'CHEMBL210195', 'CHEMBL210437', 'CHEMBL210437', 'CHEMBL378677', 'CHEMBL378677', 'CHEMBL210972', 'CHEMBL210972', 'CHEMBL210145', 'CHEMBL210145', 'CHEMBL377225', 'CHEMBL377225', 'CHEMBL210823', 'CHEMBL210823', 'CHEMBL207381', 'CHEMBL207381', 'CHEM
# ...

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)
print(canonical_smiles)
# Out:
# ['Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21', 'O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21', 'O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21', 'O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21', 'O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]', 'O=C1C(=O)N(Cc2cc3ccccc3s2)c2c(Br)cccc21', 'O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccc(F)cc21', 'O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccc(I)cc21', 'O=C1C(=O)N(Cc2cc3ccccc3s2)c2cccc(Cl)c21', 'O=C1C(=O)N(C/C=C/c2cc3ccccc3s2)c2ccc(I)cc21', 'O=C(Nc1ccc(Cl)cc1)c1ccc(CN2C(=O)C(=O)c3cc(I)ccc32)s1', 'O=C1C(=O)N(Cc2ccc(C(=O)N3CCCCC3)s2)c2ccc(I)cc21', 'CCOC(=O)/C=C/[C@H](C[C@@H]1CCNC1=O)NC(=O)[C@@H](CC(=O)[C@@H](NC(=O)c1cc(C)on1)C(C)C)Cc1ccccc1', 'CCOC(=O)/C=C/[C@H](C[C@@H]1CCNC1=O)NC(=O)[C@H](CC=C(C)C)CC(=O)[C@@H](NC(=O)c1cc(C)on1)C(C)C', 'CCCCN1C(=O)C(=O)c2cc(I)ccc21', 'NC(=O)c1ccc2c(c1)C(=O)C(=O)N2Cc1ccc2ccccc2c1', 'NC(=O)c1ccc2c(c1)C(=O)C(=O)N2Cc1ccccc1', 'CCCCN1C(=O)C(=O)c2cc(C(N)=O)ccc21', 'CCCN1C(=O)C(=O)c2cc(C(N)=O)ccc21', 'CN1C(=O)C(=O)c2cc(C(N)=O)ccc21', 'O=C1C(=O)N(Cc2ccc3ccccc3c2)c2ccc(I
# ...

# %%
standard_value=[]
for i in df2.standard_value:
  standard_value.append(i)
print(standard_value)
# Out:
# ['7200.0', '9400.0', '13500.0', '13110.0', '2000.0', '980.0', '4820.0', '950.0', '11200.0', '23500.0', '12570.0', '17500.0', '45000.0', '70000.0', '66000.0', '370.0', '12500.0', '19000.0', '25000.0', '71000.0', '1100.0', '50000.0', '3019.95', '3000.0', '301995.17', '300000.0', '251188.64', '250000.0', '204173.79', '200000.0', '100000.0', '100000.0', '60255.96', '60000.0', '45708.82', '45000.0', '40738.03', '40000.0', '15135.61', '15000.0', '15135.61', '15000.0', '12022.64', '12000.0', '1000000.0', '1000000.0', '501187.23', '500000.0', '407380.28', '400000.0', '354813.39', '350000.0', '301995.17', '300000.0', '301995.17', '300000.0', '204173.79', '200000.0', '204173.79', '200000.0', '204173.79', '200000.0', '204173.79', '200000.0', '60255.96', '60000.0', '40738.03', '40000.0', '30199.52', '30000.0', '15135.61', '15000.0', '14125.38', '14000.0', '11220.18', '11000.0', '10000.0', '10000.0', '900.0', '6000.0', '12000.0', '13000.0', '13000.0', '15000.0', '16000.0', '16000.0', '16000.0', '
# ...

# %%
#combine 4 lists into a dataframe
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame(data_tuples, columns = ['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 254      CHEMBL5595277  CC1(C)[C@@H]2[C@@H](C(=O)N[C@H](C=O)C[C@@H]3CC...
# 255      CHEMBL5570210  CC(C)c1ccc(F)c2[nH]c(C(=O)N3C[C@H]4[C@@H]([C@H...
# 256      CHEMBL5565685  CC1(C)[C@@H]2[C@@H](C(=O)N[C@H](C=O)C[C@@H]3CC...
# 257      CHEMBL5565858  CC1(C)[C@@H]2[C@@H](C(=O)N[C@H](C=O)C[C@@H]3CC...
# 258      CHEMBL4802135  CC(C)(C)[C@H](NC(=O)C(F)(F)F)C(=O)N1C[C@H]2[C@...
#
#     bioactivity_class standard_value
# 0        intermediate         7200.0
# ...

# %%
df3.to_csv('bioactivity_preprocessed_data.csv',index=False)

# %%
! ls -l
# Out:
# ls: cannot access 'drive': Transport endpoint is not connected
# total 184
# -rw-r--r-- 1 root root 152799 Feb  1 14:23 bioactivity_data.csv
# -rw-r--r-- 1 root root  22231 Feb  1 14:26 bioactivity_preprocessed_data.csv
# d????????? ? ?    ?         ?            ? drive
# drwx------ 5 root root   4096 Feb  1 14:23 gdrive
# drwxr-xr-x 1 root root   4096 Jan 16 14:24 sample_data

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data2"

# %%
# !ls "/content/gdrive/My Drive/Colab Notebooks/data2"
# Out:
# bioactivity_data.csv  bioactivity_preprocessed_data.csv
